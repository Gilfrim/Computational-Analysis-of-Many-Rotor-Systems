# %%
import numpy as np
from scipy.sparse.linalg import eigsh
from scipy.sparse import csr_matrix, kron
import os
from quant_rotor.models.density_matrix import density_matrix_1
from quant_rotor.core.hamiltonian import hamiltonian
from quant_rotor.core.hamiltonian_big import hamiltonian_general
from quant_rotor.core.t_amplitudes_periodic import t_periodic
from quant_rotor.models.t_amplitudes_guess import intermediate_normalisation, t_1_amplitude_guess_ground_state, t_2_amplitude_guess_ground_state, amplitute_energy

# %% [markdown]
# # Analisys amplitudes.

# %%
def analisis(states, sites, g, H_K_V_NO, orbital_basis: bool):

        print("g - value:", g, "\n")
        # if orbital_basis:
        #         print("Orbitals",H_K_V_NO[3], "\n")

        eig_val, eig_vec = np.linalg.eig(H_K_V_NO[0])

        t_a_i_tensor_guess = t_1_amplitude_guess_ground_state(states, sites, g, 1, eig_vec, eig_val)
        t_ab_ij_tensor_guess = t_2_amplitude_guess_ground_state(states, sites, g, 1, eig_vec, eig_val)

        d = intermediate_normalisation(eig_val, eig_vec)
        energy_guess = amplitute_energy(sites, states, g, d)

        print("Guess:")
        print("Energy:", energy_guess)
        print(f"1 max: {np.max(np.abs(t_a_i_tensor_guess))}")
        print(f"2 max: {np.max(np.abs(t_ab_ij_tensor_guess))}\n")

        energy_periodic, t_a_i_tensor_periodic, t_ab_ij_tensor_periodic, diverge = t_periodic(sites, states, 1, t_a_i_tensor_guess, t_ab_ij_tensor_guess, 1e-8, g, 3,  False, 3, False, "sin")

        if diverge:
                print("Periodic")
                print("Energy:", energy_periodic)
                print(f"1 max: {np.max(np.abs(t_a_i_tensor_periodic))}")
                print(f"2 max: {np.max(np.abs(t_ab_ij_tensor_periodic))}\n")

        return diverge

# %%
for g in range(1, 11):
    g = g/10

    H_K_V = hamiltonian(11, 3, g)

    diverge = analisis(11, 3, g, H_K_V, False)
    if diverge == False:
        break
# Out:
# g - value: 0.1
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.020101729050886804+0j)
# 1 max: 0.0011068208301983436
# 2 max: 0.03940147719527568
#
# Periodic
# Energy: (-0.020275691354355526+0j)
# 1 max: 0.0010918771775619148
# 2 max: 0.039735692511960824
#
# g - value: 0.2
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.08587361447319139+0j)
# 1 max: 0.005106720796216646
# 2 max: 0.08250491241910035
#
# Periodic
# Energy: (-0.08949768517594843+0j)
# 1 max: 0.005129946995923449
# 2 max: 0.08585988736103445
#
# g - value: 0.3
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.20438290110139917+0j)
# 1 max: 0.01283775521055892
# 2 max: 0.12850139094180468
#
# Periodic
# Energy: (-0.22874921994188815+0j)
# 1 max: 0.013768517792486817
# 2 max: 0.1430611091640107
#
# g - value: 0.4
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.37855504877506013+0j)
# 1 max: 0.024542869263947865
# 2 max: 0.17561295018329307
#
# Periodic
# Energy: (-0.4834281926837446+0j)
# 1 max: 0.029991388237132405
# 2 max: 0.22136286574856778
#
# g - value: 0.5
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.6052508273587406+1.0335674807192947e-31j)
# 1 max: 0.03966906073765983
# 2 max: 0.2215813350565542

# %%
site_max = 5
states = 5

print("Natural basis systems:")

for sites in range(5, site_max+2, 2):
    print(f"System of {sites} sites, {states} states: \n")
    for g in range(4, 11):
        g = g/10

        H_K_V_NO = hamiltonian_general(states, sites, g)
        diverge = analisis(states, sites, g, H_K_V_NO, True)

        if diverge == False:
            break
    
    states -= 2
# Out:
# Natural basis systems:
# System of 5 sites, 5 states:
#
# g - value: 0.4
#
# Guess:
# Energy: (-0.6714372286740602-5.283077283659113e-30j)
# 1 max: 0.012548601088363748
# 2 max: 0.23697810274616918

# %% [markdown]
# Natural basis systems:
# System of 3 sites, 11 states:
#
# g - value: 0.1
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.012324051965911445+4.10443249219423e-30j)
# 1 max: 7.555184320367435e-05
# 2 max: 0.05521052252269485
#
# Periodic
# Energy: (-0.020275691355311907+3.261094801579681e-39j)
# 1 max: 0.0010918771583459102
# 2 max: 0.03973569251352279
#
# g - value: 0.2
#
# System of 3 sites, 11 states:
#
#
# Guess:
# Energy: (-0.053707632154187376-1.8069241315518515e-31j)
# 1 max: 0.0006614726666203666
# 2 max: 0.1212712075080579
#
# Periodic
# Energy: (-0.0894976851757881-2.1493107464023913e-40j)
# 1 max: 0.005129946998336822
# 2 max: 0.08585988736101258
#
# g - value: 0.3
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.13011264268646264+0j)
# 1 max: 0.0022934153764508553
# 2 max: 0.19736294741872332
#
# Periodic
# Energy: (-0.22874921994179692+0j)
# 1 max: 0.01376851779307325
# 2 max: 0.14306110916401243
#
# g - value: 0.4
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.2446440138525733+0j)
# 1 max: 0.005151881489328859
# 2 max: 0.2801810275968462
#
# Periodic
# Energy: (-0.483428192683621+0j)
# 1 max: 0.02999138823734937
# 2 max: 0.2213628657483592
#
# g - value: 0.5
#
# System of 3 sites, 11 states:
#
# Guess:
# Energy: (-0.3958583980558635+2.0723958763001602e-30j)
# 1 max: 0.008773233625265857
# 2 max: 0.3645914622613367
#
# System of 5 sites, 11 states:

# %% [markdown]
# # Analisis ground states.

# %%
sites_max = 7
states = 5

print("Exact Diagnilisation:")
for sites in range(3, sites_max + 2, 2):
    print(f"System of {sites} sites, {states} states: \n")
    for g in range(4, 11):
        g = g/10

        print("g - value:", g, "\n")

        H_K_V = hamiltonian(states, sites, g)

        eig_val, eig_vec = np.linalg.eig(H_K_V[0])

        index_array = np.argsort(eig_val)
        small_states_array = np.zeros((2, 5), dtype=complex)
        for i in range(5):
            index = index_array[i]

            small_states_array[0, i] = eig_val[index]
            small_states_array[1, i] = eig_vec[0, index]

        print(f"5 Smallest Energystate and the Assosiated Eigenstate:\n", small_states_array, "\n")
# Out:
# Exact Diagnilisation:
# System of 3 sites, 5 states:
#
# g - value: 0.4
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.378314842831+0.j -0.050792984405-0.j  0.661238479607-0.j  0.661238479607+0.j  1.168611556868-0.j]
#  [ 0.892017120624+0.j -0.            -0.j  0.            -0.j -0.            -0.j  0.            -0.j]]
#
# g - value: 0.5
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.60438883019 +0.j -0.372368608344+0.j  0.530216407395+0.j  0.530216407395+0.j  1.100928376244+0.j]
#  [ 0.835375532627+0.j -0.            +0.j  0.            -0.j -0.            -0.j  0.            +0.j]]
#
# g - value: 0.6
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.874460107253+0.j -0.710340854194+0.j  0.379925656412+0.j  0.379925656412+0.j  0.873879850271+0.j]
#  [ 0.778590715207+0.j -0.            +0.j -0.            -0.j -0.            +0.j -0.            +0.j]]
#
# g - value: 0.7
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.179132370761+0.j -1.062186684887+0.j  0.21066364937 +0.j  0.21066364937 +0.j  0.634930360214+0.j]
#  [ 0.72658661501 +0.j -0.            -0.j  0.            +0.j -0.            -0.j -0.            -0.j]]
#
# g - value: 0.8
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.510149371942+0.j -1.425814871689+0.j  0.023182989998+0.j  0.023182989998+0.j  0.385503259095+0.j]
#  [ 0.68123917569 +0.j  0.            +0.j  0.            +0.j  0.            +0.j -0.            +0.j]]
#
# g - value: 0.9
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.861144080582+0.j -1.799486648613+0.j -0.181365401522+0.j -0.181365401522+0.j  0.126863827712+0.j]
#  [ 0.642549915185+0.j  0.            +0.j -0.            -0.j  0.            -0.j -0.            -0.j]]
#
# g - value: 1.0
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-2.227462413168+0.j -2.181752605937+0.j -0.401544749817+0.j -0.401544749817+0.j -0.139875463314+0.j]
#  [ 0.609745574372+0.j  0.            +0.j -0.            -0.j  0.            -0.j  0.            -0.j]]
#
# System of 5 sites, 5 states:
#
# g - value: 0.4
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.560057057311+0.j -0.315183058973-0.j  0.324676723689+0.j  0.324676723689-0.j  0.547038724239-0.j]
#  [ 0.83051511438 +0.j -0.            -0.j -0.            -0.j  0.            +0.j  0.435911108602+0.j]]
#
# g - value: 0.5
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.92483582857 +0.j -0.79137968351 -0.j  0.04225560697 -0.j  0.04225560697 +0.j  0.230733759661-0.j]
#  [ 0.716546831728+0.j -0.            +0.j -0.            +0.j  0.            -0.j  0.565007157222+0.j]]
#
# g - value: 0.6
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.381465249068+0.j -1.31171442146 +0.j -0.2893202714  -0.j -0.2893202714  -0.j -0.052855275169+0.j]
#  [ 0.604656814354+0.j -0.            -0.j  0.            +0.j  0.            -0.j  0.            +0.j]]
#
# g - value: 0.7
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.904566848248+0.j -1.867776329796+0.j -0.668886345704+0.j -0.668886345704+0.j -0.503647052961+0.j]
#  [ 0.514830954822+0.j -0.            +0.j  0.            -0.j  0.            +0.j  0.            -0.j]]
#
# g - value: 0.8
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-2.472546490147+0.j -2.452518622243+0.j -1.091769504697+0.j -1.091769504697+0.j -0.978086647869+0.j]
#  [ 0.447708926297+0.j  0.            +0.j  0.            +0.j  0.            -0.j  0.            -0.j]]
#
# g - value: 0.9
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-3.071670075646+0.j -3.060359533436+0.j -1.551218201417-0.j -1.551218201417+0.j -1.473340141909+0.j]
#  [ 0.397674553899+0.j  0.            +0.j -0.            +0.j -0.            +0.j  0.            -0.j]]
#
# g - value: 1.0
#
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-3.693588344111+0.j -3.686970486842+0.j -2.040321123994-0.j -2.040321123994-0.j -1.986766828619+0.j]
#  [ 0.359575212408+0.j  0.            +0.j  0.            -0.j  0.            +0.j  0.            -0.j]]
#
# System of 7 sites, 5 states:
#
# g - value: 0.4

# %% [markdown]
# # Saving Systems

# %%
file_path_ED = "./ED_analisis_data_sparce"

# %%
def convert_i_to_site_state(states: int, sites: int, looking_for_site: int) -> np.ndarray:

    for x in range(sites):

        n_lambda = states**(x)
        n_mu = states**(sites - x - 1)
        # Loop over the local states at the chosen site
        for p in range(states):

            # Sum over all other sites (Lambda and mu represent other sites)
            for Lambda in range(int(n_lambda)):
                for mu in range(int(n_mu)):

                    # Full indices in the Hilbert space
                    i = mu + p * n_mu + Lambda * states * n_mu

                    if i == looking_for_site:
                        return x, p

# %%
# sites = 3
# states = 11
# for g_index in range(1, 51):
#     g = g_index/10

#     print("g - value:", g, "\n")

#     H_K_V = hamiltonian(states, sites, g)

#     eig_val, eig_vec = np.linalg.eig(H_K_V[0])

#     base = f"sites{sites}_states{states}_g{g:.1f}"

#     eig_val_path = os.path.join(file_path_ED, f"eigvals_{base}.npy")
#     eig_vec_path = os.path.join(file_path_ED, f"eigvecs_{base}.npy")

#     # Save to .npy files
#     np.save(eig_val_path, eig_val)
#     np.save(eig_vec_path, eig_vec)

# %%
sites = 5
states = 3

print(f"System of {sites} sites, {states} states: \n")
for g_index in range(1, 21):
    g = g_index/10

    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = eigsh(H_K_V_NO[0], k=10, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 5 sites, 3 states:
#
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 0.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 1.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# g - value: 2.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 3 states 5 sites:

# %%
sites = 5
states = 7

print(f"System of {sites} sites, {states} states: \n")
for g_index in range(1, 21):
    g = g_index/10

    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = eigsh(H_K_V_NO[0], k=10, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 5 sites, 7 states:
#
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 0.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 1.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# g - value: 2.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 5 sites:

# %%
sites = 5
states = 9

print(f"System of {sites} sites, {states} states: \n")
for g_index in range(1, 21):
    g = g_index/10

    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = eigsh(H_K_V_NO[0], k=10, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 5 sites, 9 states:
#
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 0.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 1.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# g - value: 2.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 9 states 5 sites:

# %%
sites = 7
states = 5

print(f"System of {sites} sites, {states} states: \n")
for g_index in range(1, 21):
    g = g_index/10

    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = eigsh(H_K_V_NO[0], k=10, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 7 sites, 5 states:
#
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 0.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 1.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# g - value: 2.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 7 sites:

# %%
print(f"System of 7 sites, 5 states: \n")
for g_index in range(1, 21):

    states = 11
    sites = 3
    g = g_index / 10
    print(f"g-val: {g}")

    H = hamiltonian(states, sites, g, spar=True)

    eig_val, eig_vec = eigsh(H[0], k=(100), which='SA')

    index_array = np.argsort(eig_val)

    D_sum = np.zeros((states, states), dtype=complex)
    D_avg = np.zeros((states, states), dtype=complex)

    for i in range(6):
        D_1 = density_matrix_1(states, sites, eig_vec[:, index_array[i]], convert_i_to_site_state(states, sites, index_array[i])[0])
        D_sum += D_1

    D_avg = D_sum / 6

    print(np.trace(D_avg))

    eig_val_D, eig_vec_D = np.linalg.eig(D_avg)

    index_array_D = np.argsort(-eig_val_D)

    states = 5
    sites = 7

    matrix_p_to_natural_orbital = eig_vec_D[:, index_array_D[:states]]
    matrix_p_to_natural_orbital_sparse = csr_matrix(matrix_p_to_natural_orbital[:, index_array_D[:states]])

    K = H[1]
    V = H[2]

    print(V.shape)
    print(matrix_p_to_natural_orbital_sparse.shape)
    print(kron(matrix_p_to_natural_orbital_sparse.T.conj(), matrix_p_to_natural_orbital_sparse.T.conj()).shape)

    V = V.reshape(11**2,11**2)
    V_mu = kron(matrix_p_to_natural_orbital_sparse.T.conj(), matrix_p_to_natural_orbital_sparse.T.conj()) @ V @ kron(matrix_p_to_natural_orbital_sparse, matrix_p_to_natural_orbital_sparse)
    K_mu = matrix_p_to_natural_orbital_sparse.T.conj() @ K @ matrix_p_to_natural_orbital_sparse

    print("Check 1")

    H_new = hamiltonian(states, sites, g, 0, K_mu, V_mu, True, True)

    print("Check 2")

    eigvals_7_5, eigvecs_7_5 = eigsh(H_new[0], k=6, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 7 sites, 5 states:
#
# g-val: 0.1
# Done generating hamiltonian.
# (1.0000000000000184-6.1508971329127165e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.2
# Done generating hamiltonian.
# (1.0000000000000249+5.2532315289424846e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.3
# Done generating hamiltonian.
# (1.000000000000033-1.0636044720774553e-17j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.4
# Done generating hamiltonian.
# (1.0000000000000304-6.448053972991199e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.5
# Done generating hamiltonian.
# (1.0000000000000266+2.524819822537753e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.6
# Done generating hamiltonian.
# (1.0000000000000366+2.5449089686517994e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.7
# Done generating hamiltonian.
# (1.0000000000000244+1.9755319401563e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.8
# Done generating hamiltonian.
# (1.0000000000000169-1.4731609159294695e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 0.9
# Done generating hamiltonian.
# (1.0000000000000169-3.431793673674694e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.0
# Done generating hamiltonian.
# (1.0000000000000082-1.5464297725127664e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.1
# Done generating hamiltonian.
# (1.0000000000000164+2.4673752228478878e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.2
# Done generating hamiltonian.
# (1.0000000000000127-6.289796127097176e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.3
# Done generating hamiltonian.
# (1.0000000000000255-6.588809961636088e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.4
# Done generating hamiltonian.
# (1.0000000000000153-3.3612772368944476e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.5
# Done generating hamiltonian.
# (1.000000000000015-7.958942235928442e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.6
# Done generating hamiltonian.
# (1.0000000000000242-2.2690924077890914e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.7
# Done generating hamiltonian.
# (1.0000000000000184-9.157635564150578e-19j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.8
# Done generating hamiltonian.
# (1.0000000000000238+1.142219364154506e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 1.9
# Done generating hamiltonian.
# (1.000000000000033-3.0690432240380423e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2
# g-val: 2.0
# Done generating hamiltonian.
# (1.0000000000000244+2.1357335462258096e-18j)
# (121, 121)
# (11, 5)
# (25, 121)
# Check 1
# Done generating hamiltonian.
# Check 2

# %%
sites = 7
states = 7

print(f"System of {sites} sites, {states} states: \n")
for g_index in range(1, 21):
    g = g_index/10

    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = eigsh(H_K_V_NO[0], k=10, which='SA')

    base = f"sites{sites}_states{states}_g{g:.1f}"

    eig_val_path = os.path.join(file_path_ED, f"NO_eigvals_{base}.npy")
    eig_vec_path = os.path.join(file_path_ED, f"NO_eigvecs_{base}.npy")
    NO_basis_path = os.path.join(file_path_ED, f"NO_basis_{base}.npy")

    # Save to .npy files
    np.save(eig_val_path, eig_val)
    np.save(eig_vec_path, eig_vec)
    np.save(NO_basis_path, H_K_V_NO[3])
# Out:
# System of 7 sites, 7 states:
#
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 0.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.2
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.3
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.4
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.5
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.6
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.7
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.8
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 1.9
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# g - value: 2.0
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:
# Done change of basis.
# Done generating hamiltonian.
# Done 7 states 7 sites:

# %% [markdown]
# # Analisis Low Energy states.

# %%
sites = 3
states = 11
for g in range(1, 11):
    g = g/10
    print("g - value:", g, "\n")

    H_K_V = hamiltonian(states, sites, g)

    eig_val, eig_vec = np.linalg.eig(H_K_V[0])

    index_array = np.argsort(eig_val)
    small_states_array = np.zeros((2, 5), dtype=complex)
    for i in range(5):
        index = index_array[i]

        small_states_array[0, i] = eig_val[index]
        small_states_array[1, i] = eig_vec[0, index]

    print(f"5 Smallest Energystate and the Assosiated Eigenstate:\n", small_states_array, "\n")
# Out:
# g - value: 0.1
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.020101729051-0.j  0.781610000229-0.j  0.941735740879-0.j  0.941735740879-0.j  1.087386425962+0.j]
#  [ 0.994628485772+0.j  0.            -0.j  0.            -0.j -0.            +0.j -0.            +0.j]]
#
# g - value: 0.2
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.085873614473+0.j  0.530253986669+0.j  0.866354124445-0.j  0.866354124445-0.j  1.14669082844 +0.j]
#  [ 0.975821417076+0.j  0.            +0.j -0.            +0.j  0.            -0.j  0.            +0.j]]
#
# g - value: 0.3
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.204382901101+0.j  0.251113045583+0.j  0.772921829173+0.j  0.772921829174-0.j  1.174227514016-0.j]
#  [ 0.940979305641+0.j  0.            -0.j -0.            -0.j -0.            +0.j  0.            -0.j]]
#
# g - value: 0.4
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.378555048775+0.j -0.051507769682+0.j  0.660495627056-0.j  0.660495627056+0.j  1.167699706912+0.j]
#  [ 0.891835192101+0.j  0.            -0.j  0.            +0.j  0.            +0.j -0.            +0.j]]
#
# g - value: 0.5
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.605250827359+0.j -0.374127764865-0.j  0.528220630809-0.j  0.52822063081 +0.j  1.09551175325 +0.j]
#  [ 0.834794661385+0.j  0.            -0.j  0.            +0.j  0.            -0.j -0.            -0.j]]
#
# g - value: 0.6
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-0.876710970138-0.j -0.713939025577+0.j  0.375450343274-0.j  0.375450343274+0.j  0.863472915178+0.j]
#  [ 0.777278417364+0.j -0.            +0.j  0.            +0.j  0.            +0.j  0.            -0.j]]
#
# g - value: 0.7
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.183866965721-0.j -1.068658051557-0.j  0.201864615128+0.j  0.201864615128+0.j  0.617121548237+0.j]
#  [ 0.724222162161+0.j  0.            -0.j  0.            -0.j  0.            +0.j  0.            -0.j]]
#
# g - value: 0.8
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.518721110984+0.j -1.436407431319-0.j  0.007554224015+0.j  0.007554224016-0.j  0.357495246384+0.j]
#  [ 0.677565859186+0.j  0.            -0.j -0.            +0.j  0.            -0.j -0.            -0.j]]
#
# g - value: 0.9
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-1.87509239644 -0.j -1.815627161728+0.j -0.206953945298-0.j -0.206953945298-0.j  0.085548985797-0.j]
#  [ 0.637380702515+0.j  0.            -0.j -0.            +0.j -0.            +0.j  0.            -0.j]]
#
# g - value: 1.0
#
# Done generating hamiltonian.
# 5 Smallest Energystate and the Assosiated Eigenstate:
#  [[-2.248454586348+0.j -2.205008851974-0.j -0.440738813563-0.j -0.440738813563-0.j -0.197841030569+0.j]
#  [ 0.602949918025+0.j  0.            +0.j -0.            -0.j -0.            -0.j  0.            +0.j]]

# %%
sites = 3
states = 5
for g in range(1, 11):
    g = g/10
    print("g - value:", g, "\n")

    H_K_V_NO = hamiltonian_general(states, sites, g)

    eig_val, eig_vec = np.linalg.eig(H_K_V_NO[0])

    index_array = np.argsort(eig_val)
    small_states_array = np.zeros((2, 5), dtype=complex)
    for i in range(5):
        index = index_array[i]

        small_states_array[0, i] = eig_val[index]
        small_states_array[1, i] = eig_vec[0, index]

    print(f"5 Smallest Energystate and the Assosiated Eigenstate:\n", small_states_array, "\n")

    print("Density 5 Energystates:\n")
    print(H_K_V_NO[4])

    t_a_i_tensor_guess = t_1_amplitude_guess_ground_state(states, sites, g, 1, eig_vec, eig_val)
    t_ab_ij_tensor_guess = t_2_amplitude_guess_ground_state(states, sites, g, 1, eig_vec, eig_val)

    _, _, t_2, diverge = t_periodic(sites, states, 1, t_a_i_tensor_guess, t_ab_ij_tensor_guess, 1e-8, g, 3,  False, 3, False, "sin")

    largest_t_2 = np.max(np.abs(t_2))

    print("t_2", largest_t_2)

    # print("Density:\n")
    # print(H_K_V_NO[3])
# Out:
# g - value: 0.1
#
# Done generating hamiltonian.
# Done change of basis.
# Done generating hamiltonian.
# Done 5 states 3 sites:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[17], line 9
#       5 print("g - value:", g, "\n")
#       7 H_K_V_NO = hamiltonian_general(states, sites, g)
# ----> 9 eig_val, eig_vec = np.linalg.eig(H_K_V_NO[0])
#      11 index_array = np.argsort(eig_val)
#      12 small_states_array = np.zeros((2, 5), dtype=complex)
#
# File ~/Desktop/Projects/Computational_Analisis_of_Many_Rotor_Systems/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:1463, in eig(a)
#    1333 """
#    1334 Compute the eigenvalues and right eigenvectors of a square array.
#    1335
#    (...)   1460
#    1461 """
#    1462 a, wrap = _makearray(a)
# -> 1463 _assert_stacked_2d(a)
#    1464 _assert_stacked_square(a)
#    1465 _assert_finite(a)
#
# File ~/Desktop/Projects/Computational_Analisis_of_Many_Rotor_Systems/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:195, in _assert_stacked_2d(*arrays)
#     193 for a in arrays:
#     194     if a.ndim < 2:
# --> 195         raise LinAlgError('%d-dimensional array given. Array must be '
#     196                 'at least two-dimensional' % a.ndim)
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional
